# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo 2

# %% [markdown]
# ## Integrantes:
# * Axel Rivera - 202204056-4
# * Andres Araya - 202287004-4
# * Andres Restrepo - 202051046-6

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:12345678@localhost:5432/db
# Out:
# env: DATABASE_URL=postgresql://postgres:12345678@localhost:5432/db

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='db',
   password="12345678"
)

print(conn)
# Out:
# <connection object at 0x000001C5556997A0; dsn: 'user=postgres password=xxx dbname=db host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director (
#     id_director INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER NOT NULL,
#     PRIMARY KEY(id_director)
# )
# Out:
# (psycopg2.errors.DuplicateTable) la relación «director» ya existe
#
# [SQL: CREATE TABLE director (
#     id_director INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER NOT NULL,
#     PRIMARY KEY(id_director)
# )]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (
#     id_actor INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER NOT NULL,
#     PRIMARY KEY (id_actor)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (
#     id_pelicula INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INTEGER NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INTEGER,
#     id_pelicula INTEGER,
#     FOREIGN KEY (id_actor) REFERENCES actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula),
#     PRIMARY KEY (id_pelicula, id_actor)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# Done.
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_director» ya existe
#
# [SQL: CREATE TABLE premio_mejor_director (
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_actor INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio),
#     FOREIGN KEY (id_actor) REFERENCES actor (id_actor)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))

for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1987, 'director': 33, 'genero': 'Suspense', 'cast': [49], 'mejor pelicula': 'no'}, 2: {'año': 2011, 'director': 59, 'genero': 'Suspense', 'cast': [44], 'mejor pelicula': 'no'}, 3: {'año': 2016, 'director': 196, 'genero': 'Animación', 'cast': [194], 'mejor pelicula': 'no'}, 4: {'año': 2009, 'director': 153, 'genero': 'Romance', 'cast': [58], 'mejor pelicula': 'no'}, 5: {'año': 1999, 'director': 112, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 6: {'año': 1977, 'director': 89, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 7: {'año': 1982, 'director': 135, 'genero': 'Misterio', 'cast': [117, 65, 9], 'mejor pelicula': 'no'}, 8: {'año': 2016, 'director': 26, 'genero': 'Fantasía', 'cast': [104, 192], 'mejor pelicula': 'no'}, 9: {'año': 1967, 'director': 194, 'genero': 'Western', 'cast': [44], 'mejor pelicula': 'no'}, 10: {'año': 2016, 'director': 49, 'genero': 'Misterio', 'cast': [19, 83, 24], 'mejor pelicula': 'no'}, 11: {'año': 1961, 'director': 184, 'genero': 'Western', 'cast': [47], 'mejor pelicula': 'no'}, 12: {'año': 1975, 'director': 61, 'genero': 'Drama', 'cast': [134, 81], 'mejor pelicula': 'no'}, 13: {'año': 2015, 'director': 190, 'genero': 'Animación', 'cast': [], 'mejor pelicula': 'no'}, 14: {'año': 1971, 'director': 16, 'genero': 'Drama', 'cast': [149, 68], 'mejor pelicula': 'no'}, 15: {'año': 1979, 'director': 175, 'genero': 'Drama', 'cast': [193], 'mejor pelicula': 'no'}, 16: {'año': 2009, 'director': 153, 'genero': 'Comedia', 'cast': [185], 'mejor pelicula': 'no'}, 17: {'año': 1986, 'director': 157, 'genero': 'Comedia', 'cast': [86, 126, 2], 'mejor pelicula': 'no'}, 18: {'año': 1960, 'director': 126, 'genero': 'Misterio', 'cast': [113, 8, 142, 121, 152], 'mejor pelicula': 'no'}, 19: {'año': 2014, 'director': 76, 'genero': 'Romance', 'cast': [126, 38], 'mejor pelicula': 'no'}, 20: {'año': 1965, 'director': 119, 'genero': 'Fantasía', 'cast': [80], 'mejor pelicula': 'no'}, 21: {'año': 2009, 'director': 158, 'genero': 'Comedia', 'cast': [85, 39, 51], 'mejor pelicula': 'no'}, 22: {'año': 1998, 'director': 70, 'genero': 'Comedia', 'cast': [76, 42], 'mejor pelicula': 'no'}, 23: {'año': 1996, 'director': 87, 'genero': 'Fantasía', 'cast': [171], 'mejor pelicula': 'no'}, 24: {'año': 1984, 'director': 171, 'genero': 'Western', 'cast': [105], 'mejor pelicula': 'no'}, 25: {'año': 2014, 'director': 105, 'genero': 'Misterio', 'cast': [74], 'mejor pelicula': 'no'}, 26: {'año': 1985, 'director': 194, 'genero': 'Acción', 'cast': [78, 43, 160], 'mejor pelicula': 'no'}, 27: {'año': 2008, 'director': 99, 'genero': 'Western', 'cast': [126, 72], 'mejor pelicula': 'no'}, 28: {'año': 2016, 'director': 94, 'genero': 'Acción', 'cast': [63], 'mejor pelicula': 'no'}, 29: {'año': 2016, 'director': 192, 'genero': 'Acción', 'cast': [30], 'mejor pelicula': 'no'}, 30: {'año': 1979, 'director': 44, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 31: {'año': 1963, 'director': 82, 'genero': 'Misterio', 'cast': [151, 167, 117], 'mejor pelicula': 'no'}, 32: {'año': 2008, 'director': 136, 'genero': 'Comedia', 'cast': [153, 177], 'mejor pelicula': 'no'}, 33: {'año': 2020, 'director': 163, 'genero': 'Comedia', 'cast': [47], 'mejor pelicula': 'no'}, 34: {'año': 1977, 'director': 89, 'genero': 'Aventura', 'cast': [180], 'mejor pelicula': 'no'}, 35: {'año': 1982, 'director': 51, 'genero': 'Western', 'cast': [190], 'mejor pelicula': 'no'}, 36: {'año': 1992, 'director': 18, 'genero': 'Suspense', 'cast': [184], 'mejor pelicula': 'no'}, 37: {'año': 2011, 'director': 166, 'genero': 'Musical', 'cast': [104], 'mejor pelicula': 'no'}, 38: {'año': 2017, 'director': 21, 'genero': 'Documental', 'cast': [30, 167, 186, 15, 60], 'mejor pelicula': 'no'}, 39: {'año': 2020, 'director': 116, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 40: {'año': 1979, 'director': 80, 'genero': 'Suspense', 'cast': [192, 49, 158], 'mejor pelicula': 'no'}, 41: {'año': 2001, 'director': 143, 'genero': 'Suspense', 'cast': [146, 14, 161],  ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Se seleccionan todos los nombres de las películas en la tabla 'pelicula' que hayan sido publicadas desde el 01 de Enero de 2023 y se ordenan de forma descendiente._

# %%
# %%sql
# SELECT
#     nombre
# FROM
#     pelicula
# WHERE
#     fecha_publicacion >= '2023-01-1'
# ORDER BY
#     fecha_publicacion DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 4 rows affected.
# [('La sombra de la profecía',),
#  ('La maldición del vampiro de la profecía',),
#  ('El vuelo mágico de la cárcel',),
#  ('La fuente de el océano',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Se seleccionan los nombres y fechas de publicación de las películas en la tabla 'película' que tengan como género 'Drama' y que hayan sido publicadas en 2023._

# %%
# %%sql
# SELECT
#     nombre, fecha_publicacion, genero
# FROM
#     pelicula
# WHERE
#     genero = 'Drama'
#     AND EXTRACT(YEAR FROM fecha_publicacion) = 2023
# ORDER BY
#     fecha_publicacion DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** Se hace un INNER JOIN entre la tabla 'pelicula' y 'actor_participa_en_pelicula', para luego hacer otro INNER JOIN entre 'actor_participa_en_pelicula' y 'actor', de eso modo se obtiene una tabla con los actores asociados a las películas en donde participan. Desde ahí, se selecciona solo los nombres de aquellos actores que participen en películas con el género de 'Comedia'.

# %%
# %%sql
# SELECT DISTINCT
# 	actor.nombre AS actor
# FROM
# 	actor
# 	JOIN actor_participa_en_pelicula
# 		ON actor.id_actor = actor_participa_en_pelicula.id_actor
# 	JOIN pelicula
# 		ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# WHERE
# 	genero = 'Comedia'
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 43 rows affected.
# [('Kamala Abadi',),
#  ('Khaled Carvalho',),
#  ('Fatemeh Uchoa',),
#  ('Wan Ortega',),
#  ('Nina Zhang',),
#  ('Leonardo Goncalves',),
#  ('Yusef Nogueira',),
#  ('Wang Oliveira',),
#  ('Theresa Yamamoto',),
#  ('Hiroko Inácio',),
#  ('Chen Ueno',),
#  ('Kamala Santos',),
#  ('Xin Velez',),
#  ('Theresa Estevez',),
#  ('Hanako Xavier',),
#  ('Bianca Xu',),
#  ('Alessandro Xavier',),
#  ('Abdullah Montenegro',),
#  ('Javier Borges',),
#  ('Isa Santana',),
#  ('Han Alvarez',),
#  ('Umar Joaquim',),
#  ('Rashid Teixeira',),
#  ('Hanako Goncalves',),
#  ('Yusef Figueiredo',),
#  ('Orhan Vargas',),
#  ('Yusef Dutta',),
#  ('Leonardo Olivares',),
#  ('Zafar Wu',),
#  ('Hanako Uchoa',),
#  ('Zoya Lopez',),
#  ('Yusef Qian',),
#  ('Tatiana Dutta',),
#  ('Elena Alvarez',),
#  ('Valentina Uchoa',),
#  ('Rosa Wu',),
#  ('Natalia Yan',),
#  ('Lakshmi Janssen',),
#  ('Giovanni Quintana',),
#  ('Yasmin Santana',),
#  ('Valentina Olivares',),
#  ('Khaled Barros',),
#  ('Umberto Almeida',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Se hace un INNER JOIN entre la tabla 'pelicula' y 'premio_mejor_pelicula' para filtrar solo las películas que tuvieron algún premio. Luego se agrupa por genero y se hace u ._

# %%
# %%sql
# SELECT
#     pelicula.genero, COUNT(premio_mejor_pelicula.id_premio) AS premios
# FROM
#     pelicula
#     JOIN premio_mejor_pelicula
#     ON pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
# GROUP BY
#     pelicula.genero
# ORDER BY
#     COUNT(premio_mejor_pelicula.id_premio) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 13 rows affected.
# [('Drama', 5),
#  ('Western', 4),
#  ('Romance', 4),
#  ('Animación', 4),
#  ('Documental', 3),
#  ('Acción', 3),
#  ('Fantasía', 3),
#  ('Aventura', 2),
#  ('Musical', 2),
#  ('Comedia', 2),
#  ('Misterio', 2),
#  ('Suspense', 1),
#  ('Terror', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.nombre AS "Nombre",
#     COUNT(actor_participa_en_pelicula.id_actor) AS "Cantidad de actores"
# FROM
#     pelicula
# JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# GROUP BY
#     pelicula.id_pelicula, pelicula.nombre
# HAVING
#     COUNT(actor_participa_en_pelicula.id_actor) >= 2
# ORDER BY
#     COUNT(actor_participa_en_pelicula.id_actor) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 148 rows affected.
# [('El enigma de la esperanza', 6),
#  ('El vuelo mágico de el misterio', 5),
#  ('El secreto oscuro de la fortuna', 5),
#  ('La búsqueda del tesoro de la espada mágica', 5),
#  ('El pacto de el camino', 5),
#  ('La travesura de el viaje', 5),
#  ('El refugio de la fuga', 5),
#  ('El laberinto de la verdad', 5),
#  ('El vuelo de la flor', 4),
#  ('La cripta de la tierra', 4),
#  ('La travesía de el amanecer', 4),
#  ('La sombra de la senda', 4),
#  ('El vuelo mágico de la cárcel', 4),
#  ('La escalada de el guardián', 4),
#  ('El ritual de la revelación', 4),
#  ('La llegada de la batalla', 4),
#  ('La conquista de la ley', 4),
#  ('El renacimiento de la caza', 4),
#  ('La trampa de el guerrero', 4),
#  ('La senda de la criatura', 4),
#  ('El misterio de la oscuridad', 4),
#  ('La estirpe de el bosque', 3),
#  ('La estirpe de la fortuna', 3),
#  ('La venganza de la pesadilla', 3),
#  ('El secreto oscuro de la ciudad', 3),
#  ('El vuelo de la batalla', 3),
#  ('La fuente de la noche', 3),
#  ('El lamento de la gárgola', 3),
#  ('La sombra de la fuga', 3),
#  ('La estrella fugaz de el caos', 3),
#  ('El descubrimiento de la libertad', 3),
#  ('La travesura de el muro', 3),
#  ('La profecía de la luna', 3),
#  ('El tesoro escondido de el abismo', 3),
#  ('El tesoro escondido de el hechizo', 3),
#  ('El hechizo de la resistencia', 3),
#  ('La senda de el peligro', 3),
#  ('La travesura de la guerra', 3),
#  ('El laberinto de el héroe', 3),
#  ('El guardián de el laberinto', 3),
#  ('La travesía sin retorno de la senda', 3),
#  ('El pacto de el enigma', 3),
#  ('El arco iris de la pesadilla', 3),
#  ('La tormenta de el río', 3),
#  ('El caballero de la fuga', 3),
#  ('El pacto de el río', 3),
#  ('La fuente de la cueva', 3),
#  ('El destino de la libertad', 3),
#  ('El resurgimiento de el guardián', 3),
#  ('La búsqueda de la magia', 3),
#  ('El pacto de el mago', 3),
#  ('El vuelo mágico de el viaje', 3),
#  ('El último viaje de el enigma', 3),
#  ('El descubrimiento de la luna', 3),
#  ('La resurrección de la magia', 3),
#  ('La danza de la bruma', 3),
#  ('El hechizo de el lamento', 3),
#  ('La metamorfosis de el unicornio', 3),
#  ('El prisionero de la corona', 3),
#  ('El secreto de el rey', 3),
#  ('El canto de sirena de el león', 3),
#  ('El destino de el legado', 3),
#  ('La resurrección de el faro', 3),
#  ('La cripta de la bruma', 3),
#  ('La llave de la muralla', 3),
#  ('La historia de el encuentro', 3),
#  ('El último viaje de la muralla', 3),
#  ('El último viaje de el héroe', 2),
#  ('El refugio de el perdón', 2),
#  ('La maldición del vampiro de la leyenda', 2),
#  ('La leyenda de el abismo', 2),
#  ('El pacto de la montaña', 2),
#  ('El eclipse de el ángel', 2),
#  ('El despertar de el amanecer', 2),
#  ('La sombra de el sueño', 2),
#  ('El último viaje de el susurro', 2),
#  ('La travesía sin retorno de el ángel', 2),
#  ('La invasión de el hechicero', 2),
#  ('La canción de la leyenda', 2),
#  ('La senda de el guardián', 2),
#  ('La travesía sin retorno de el atardecer', 2),
#  ('El caballero de el faro', 2),
#  ('La invasión de la noche', 2),
#  ('La senda de el amor', 2),
#  ('La búsqueda del tesoro de el guardián', 2),
#  ('El secreto de la estrella fugaz', 2),
#  ('La conquista de el sol', 2),
#  ('La escalada de la magia', 2),
#  ('La resurrección de la luz', 2),
#  ('La maldición del vampiro de la gárgola', 2),
#  ('El secreto oscuro de la heroína', 2),
#  ('El hechizo de la compañía', 2),
#  ('La danza de el puente', 2),
#  ('La canción de el grito', 2),
#  ('La venganza de la sonrisa', 2),
#  ('La maldición de la noche', 2),
#  ('La canción de la montaña', 2),
#  ('El despertar de la nube', 2),
#  ('El amanecer de el mito', 2),
#  ('La travesía del océano de la expedición', 2),
#  ('La maldición del vampiro de la sombra', 2),
#  ('El castillo de la resistencia', 2),
#  ('La tormenta de el renacer', 2),
#  ('La odisea de la oscuridad', 2),
#  ('El grito de la pesadilla', 2),
#  ('El renacimiento de la noche', 2),
#  ('La fuente de el renacimiento', 2),
#  ('La búsqueda de la batalla', 2),
#  ('El espejismo de la pesadilla', 2),
#  ('El tesoro escondido de el caos', 2),
#  ('La danza macabra de el bosque', 2),
#  ('El camino hacia la pesadilla', 2),
#  ('La sombra de la profecía', 2),
#  ('La invasión de la cripta', 2),
#  ('El enigma de la huida', 2),
#  ('La escalada de la traición', 2),
#  ('La redención de el destino', 2),
#  ('El refugio de la prisión', 2),
#  ('La tormenta de la sirena', 2),
#  ('El vuelo mágico de el castillo', 2),
#  ('El viaje de la fortuna', 2),
#  ('El príncipe de el laberinto', 2),
#  ('La travesía de el destino', 2),
#  ('La senda de la espada mágica', 2),
#  ('La misión de la caída', 2),
#  ('El tesoro escondido de el viajero', 2),
#  ('La leyenda de el unicornio', 2),
#  ('El renacimiento de la cripta', 2),
#  ('El descubrimiento de la aventura', 2),
#  ('El arco iris de la trampa', 2),
#  ('La estirpe de el ángel', 2),
#  ('El destino de el rincón', 2),
#  ('La venganza de la batalla', 2),
#  ('El arco iris de el río', 2),
#  ('El cuento de hadas de el abismo', 2),
#  ('El vuelo mágico de el ángel', 2),
#  ('La travesía del océano de el legado', 2),
#  ('La redención de la selva', 2),
#  ('El despertar de la cárcel', 2),
#  ('El prisionero de la oscuridad', 2),
#  ('La batalla de el unicornio', 2),
#  ('La trampa de la muralla', 2),
#  ('La leyenda de el renacimiento', 2),
#  ('El despertar de la estrella fugaz', 2),
#  ('El espejismo de el monstruo', 2),
#  ('La tormenta de el mago', 2),
#  ('La travesía sin retorno de la gruta', 2),
#  ('La senda de el renacimiento', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.nombre AS "Nombre",
#     MIN(actor.edad) AS "Edad del actor más joven",
#     MAX(actor.edad) AS "Edad del actor más viejo"
# FROM
#     pelicula
# JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# JOIN
#     actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# GROUP BY
#     pelicula.id_pelicula, pelicula.nombre
# ORDER BY
#     MAX(actor.edad) - MIN(actor.edad) DESC
# LIMIT
#     1;
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 1 rows affected.
# [('El pacto de el enigma', 18, 70)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     DISTINCT premio_mejor_pelicula.anio AS "Año"
# FROM
#     premio_mejor_pelicula
# JOIN
#     pelicula ON premio_mejor_pelicula.id_pelicula = pelicula.id_pelicula
# WHERE
#     pelicula.duracion = (
#         SELECT
#             MAX(duracion)
#         FROM
#             pelicula
#     )
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre AS "Nombre del actor",
#     COUNT(DISTINCT director.nombre) AS "Cantidad de directores",
#     MIN(pelicula.nombre) AS "Nombre de una película"
# FROM
#     actor
# JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# JOIN
#     director ON pelicula.id_director = director.id_director
# GROUP BY
#     actor.nombre
# HAVING
#     COUNT(DISTINCT director.nombre) > 1
# ORDER BY
#     COUNT(DISTINCT director.nombre) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 136 rows affected.
# [('Yusef Qian', 7, 'El refugio de la reina'),
#  ('Hiroko Inácio', 7, 'El príncipe de el laberinto'),
#  ('Yasmin Joaquim', 6, 'El pacto de el camino'),
#  ('Patricia Lima', 6, 'El descubrimiento de la aventura'),
#  ('Lakshmi Henriquez', 6, 'El destino de la libertad'),
#  ('Yusef Nogueira', 6, 'El despertar de la nube'),
#  ('Khaled Hidalgo', 6, 'El despertar de el amanecer'),
#  ('Wan Ortega', 6, 'El enigma de el río'),
#  ('Natalia Vargas', 5, 'El secreto oscuro de la fortuna'),
#  ('Nadia Gomes', 5, 'El renacimiento de la caza'),
#  ('Mina Watanabe', 5, 'El refugio de la fuga'),
#  ('Mehmet Ferreira', 5, 'El castillo de la resistencia'),
#  ('Lakshmi Janssen', 5, 'El descubrimiento de la aventura'),
#  ('Emiko Nunes', 5, 'El secreto de la estrella fugaz'),
#  ('Khaled Carvalho', 5, 'El despertar de la bruma'),
#  ('Kamala Diniz', 5, 'El enigma de la esperanza'),
#  ('Hanako Uchoa', 5, 'El secreto de la perdición'),
#  ('Zoya Vargas', 5, 'El bosque encantado de el destino'),
#  ('Xin Martinez', 5, 'El bosque encantado de la tierra'),
#  ('Salim Kawaguchi', 5, 'El laberinto de la verdad'),
#  ('Abdullah Montenegro', 5, 'El despertar de la cárcel'),
#  ('Ximena Tan', 4, 'El amanecer de el mito'),
#  ('Beatriz Iglesias', 4, 'El camino hacia la pesadilla'),
#  ('Bianca Iglesias', 4, 'La escalada de la traición'),
#  ('Chidike Gao', 4, 'El pacto de el mago'),
#  ('Elif Wu', 4, 'El destino de la libertad'),
#  ('Fatemeh Dutta', 4, 'El renacimiento de la noche'),
#  ('Hiroko Sousa', 4, 'El castillo de la resistencia'),
#  ('Irina Lopez', 4, 'El espejismo de el vuelo'),
#  ('Irina Rocha', 4, 'El grito de la pesadilla'),
#  ('Isa Martinez', 4, 'El secreto oscuro de la fortuna'),
#  ('Leonardo Olivares', 4, 'El caballero de la aventura'),
#  ('Leonardo Sousa', 4, 'El hechizo de la resistencia'),
#  ('Mina Gao', 4, 'El vuelo mágico de el viaje'),
#  ('Nadia Vargas', 4, 'El renacimiento de la cripta'),
#  ('Omar Abadi', 4, 'El grito de la pesadilla'),
#  ('Oscar Vargas', 4, 'El misterio de la oscuridad'),
#  ('Quintus Olivares', 4, 'El destino de el rincón'),
#  ('Rashid Barros', 4, 'El cuento de hadas de el abismo'),
#  ('Rashid Teixeira', 4, 'El hechizo de la resistencia'),
#  ('Rosa Wu', 4, 'El laberinto de el rincón'),
#  ('Salim Vargas', 4, 'La escalada de la luz'),
#  ('Samir Nogueira', 4, 'El pacto de el río'),
#  ('Tatiana Alvarez', 4, 'El pacto de el enigma'),
#  ('Tatiana Dutta', 4, 'El enigma de la esperanza'),
#  ('Theresa Yamamoto', 4, 'El canto de sirena de el león'),
#  ('Valentina Olivares', 4, 'El destino de el legado'),
#  ('Wang Gao', 4, 'El arco iris de la pesadilla'),
#  ('Wang Joaquim', 4, 'El vuelo de la batalla'),
#  ('Wang Oliveira', 4, 'El enigma de la huida'),
#  ('Yuri Zambrano', 4, 'El pacto de el camino'),
#  ('Yusef Figueiredo', 4, 'El espejismo de el monstruo'),
#  ('Zara Barros', 4, 'El secreto oscuro de la ciudad'),
#  ('Yusef Vieira', 3, 'El laberinto de la verdad'),
#  ('Darya Xu', 3, 'El misterio de el amanecer'),
#  ('Leonardo Goncalves', 3, 'La canción de la leyenda'),
#  ('Umberto Pacheco', 3, 'El laberinto de la verdad'),
#  ('Umberto Ramos', 3, 'El prisionero de la oscuridad'),
#  ('Orhan Vargas', 3, 'El caballero de el faro'),
#  ('Ximena Jimenez', 3, 'El tesoro escondido de la caza'),
#  ('Valentina Martinez', 3, 'El pacto de el mago'),
#  ('Zafar Henriquez', 3, 'El camino hacia el grito'),
#  ('Valentina Uchoa', 3, 'El eclipse de el ángel'),
#  ('Bianca Xu', 3, 'El ritual de la revelación'),
#  ('Chen Ueno', 3, 'El ritual de la revelación'),
#  ('Parvati Zhang', 3, 'El refugio de la fuga'),
#  ('Chiyoko Ivanov', 3, 'El arco iris de el río'),
#  ('Darya Kawaguchi', 3, 'El secreto de la estrella fugaz'),
#  ('Khaled Vieira', 3, 'El despertar de la cárcel'),
#  ('Ximena Nguyen', 3, 'El bosque encantado de la expedición'),
#  ('Yasmin Santana', 3, 'El destino de el legado'),
#  ('Han Barros', 3, 'El misterio de la oscuridad'),
#  ('Hanako Rodriguez', 3, 'El hechizo de la resistencia'),
#  ('Fatemeh Sousa', 3, 'El guardián de el laberinto'),
#  ('Hanako Xavier', 3, 'El vuelo mágico de el castillo'),
#  ('Elif Ramos', 3, 'El regreso de el vuelo'),
#  ('Darius Yilmaz', 3, 'El hechizo de el lamento'),
#  ('Hiroko Lima', 3, 'El despertar de la estrella fugaz'),
#  ('Hiroko Montenegro', 3, 'El caballero de la fuga'),
#  ('Yusef Dutta', 3, 'El espejismo de la pesadilla'),
#  ('Kamala Santos', 3, 'El eclipse de el ángel'),
#  ('Wang Gomes', 3, 'El vuelo de la flor'),
#  ('Aarav Yamamoto', 3, 'El descubrimiento de la libertad'),
#  ('Lakshmi Ramos', 3, 'El cuento de hadas de el abismo'),
#  ('Isa Quintana', 3, 'El lamento de la gárgola'),
#  ('Isa Santana', 3, 'La canción de el grito'),
#  ('Javier Borges', 3, 'El vuelo mágico de el castillo'),
#  ('Abdullah Lopez', 3, 'El pacto de el río'),
#  ('Jin Vargas', 3, 'El vuelo mágico de el misterio'),
#  ('Aarav Pereira', 3, 'El último viaje de el enigma'),
#  ('Theresa Estevez', 3, 'El arco iris de la trampa'),
#  ('Fadhila Kawaguchi', 2, 'El guardián de la sirena'),
#  ('Zafar Wu', 2, 'El caballero de la compañía'),
#  ('Ilya Esteves', 2, 'El enigma de la esperanza'),
#  ('Zara Martinez', 2, 'El secreto oscuro de la prisión'),
#  ('Javier Sousa', 2, 'El amanecer de el mito'),
#  ('Kamala Abadi', 2, 'El descubrimiento de la luna'),
#  ('Kamala Pereira', 2, 'La escalada de la magia'),
#  ('Fadhila Fernandes', 2, 'La metamorfosis de el unicornio'),
#  ('Kamala Zhang', 2, 'La estirpe de el caos'),
#  ('Katarina Wu', 2, 'El viaje de la fortuna'),
#  ('Fadhila Carvalho', 2, 'La resurrección de la luz'),
#  ('Fabiana Quintana', 2, 'El laberinto de el héroe'),
#  ('Elena Henriquez', 2, 'El despertar de la estrella fugaz'),
#  ('Wilhelmina Ramos', 2, 'El enigma de la esperanza'),
#  ('Xavier Iglesias', 2, 'La travesía del océano de el legado'),
#  ('Leonardo Zambrano', 2, 'El prisionero de la corona'),
#  ('Leticia Lopes', 2, 'El hechizo de la flor'),
#  ('Mikhail Pacheco', 2, 'El arco iris de la pesadilla'),
#  ('Darya Abadi', 2, 'La escalada de el guardián'),
#  ('Nadia Xia', 2, 'El arco iris de el río'),
#  ('Natalia Yan', 2, 'La canción de la montaña'),
#  ('Nina Zhang', 2, 'El canto de sirena de el león'),
#  ('Omar Quintana', 2, 'El vuelo de la flor'),
#  ('Orhan Kawaguchi', 2, 'El último viaje de el enigma'),
#  ('Oscar Hidalgo', 2, 'El hechizo de el lamento'),
#  ('Pilar Kawaguchi', 2, 'El pacto de el enigma'),
#  ('Xin Velez', 2, 'El resurgimiento de el guardián'),
#  ('Alessandro Xavier', 2, 'El caballero de el faro'),
#  ('Zara Vargas', 2, 'El descubrimiento de la libertad'),
#  ('Chen Vargas', 2, 'El arco iris de la trampa'),
#  ('Zoya Lopez', 2, 'El caballero de la fuga'),
#  ('Abdullah Urbina', 2, 'La travesía del océano de la expedición'),
#  ('Tatjana Almeida', 2, 'El vuelo mágico de la cárcel'),
#  ('Umar Joaquim', 2, 'El resurgimiento de el guardián'),
#  ('Umberto Almeida', 2, 'La cripta de la tierra'),
#  ('Umberto Uchoa', 2, 'El hechizo de la compañía'),
#  ('Ursula Carvalho', 2, 'El caballero de la fuga'),
#  ('Valeria Vargas', 2, 'La invasión de la libertad'),
#  ('Genghis Kumar', 2, 'La redención de el destino'),
#  ('Genghis Lopez', 2, 'La senda de el guardián'),
#  ('Genghis Yilmaz', 2, 'La maldición del vampiro de el puente'),
#  ('Giovanni Abadi', 2, 'El vuelo mágico de el misterio'),
#  ('Giovanni Quintana', 2, 'El ritual de la revelación'),
#  ('Han Alvarez', 2, 'La senda de el amor'),
#  ('Hiroko Gao', 2, 'El enigma de la esperanza')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Se eligen los nombres de actores, utilizando join en las tablas actor, pelicula y actor_participa en pelicula, verificando que el ID del director de la pelicula sea 1 y para confirmar que solo participen en sus peliculas, se verifica que no participen en peliculas dirigidas por directores de ID distinta de 1._

# %%
# %%sql
# SELECT DISTINCT
#     actor.nombre AS "Nombre"
# FROM
#     actor
# JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# WHERE
#     pelicula.id_director = 1
#     AND actor.id_actor NOT IN (
#         SELECT DISTINCT
#             actor.id_actor
#         FROM
#             actor
#         JOIN
#             actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
#         JOIN
#             pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
#         WHERE
#             pelicula.id_director != 1
#     );
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# WITH ActorFilmDirectorInfo AS (
#     SELECT
#         actor.nombre AS "Nombre del actor",
#         pelicula.nombre AS "Nombre de la película",
#         director.nombre AS "Nombre del director",
#         COUNT(*) OVER (PARTITION BY pelicula.id_director) AS "Número de películas del director",
#         COUNT(premio_mejor_director.id_premio) OVER (PARTITION BY pelicula.id_director) AS "Número de premios del director"
#     FROM
#         actor
#     JOIN
#         actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
#     JOIN
#         pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
#     JOIN
#         director ON pelicula.id_director = director.id_director
#     LEFT JOIN
#         premio_mejor_director ON director.id_director = premio_mejor_director.id_director
#     WHERE
#         actor.id_actor NOT IN (
#             SELECT DISTINCT
#                 actor.id_actor
#             FROM
#                 actor
#             JOIN
#                 actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
#             JOIN
#                 premio_mejor_actor ON actor.id_actor = premio_mejor_actor.id_actor
#         )
# )
# SELECT
#     *
# FROM
#     ActorFilmDirectorInfo
# ORDER BY
#     "Nombre del actor", "Nombre de la película";
# Out:
#  * postgresql://postgres:***@localhost:5432/db
# 403 rows affected.
# [('Aarav Pereira', 'El último viaje de el enigma', 'Qiu Tan', 3, 0),
#  ('Aarav Pereira', 'La trampa de el guerrero', 'Hiroko Uchoa', 3, 3),
#  ('Aarav Pereira', 'La travesía del océano de el legado', 'Ximena Wu', 2, 0),
#  ('Aarav Teles', 'La travesía sin retorno de el atardecer', 'Valentina Lima', 6, 0),
#  ('Aarav Yamamoto', 'El descubrimiento de la libertad', 'Darya Hernandez', 4, 0),
#  ('Aarav Yamamoto', 'La leyenda de el renacimiento', 'Genghis Tan', 9, 0),
#  ('Aarav Yamamoto', 'La travesía de el destino', 'Patricia Oliveira', 6, 0),
#  ('Abdullah Lopez', 'El pacto de el río', 'Wan Bianchi', 7, 7),
#  ('Abdullah Lopez', 'El último viaje de el muro', 'Xavier Barros', 3, 0),
#  ('Abdullah Lopez', 'La travesía sin retorno de la gruta', 'Umberto Quintana', 4, 0),
#  ('Abdullah Montenegro', 'El despertar de la cárcel', 'Rania Correia', 3, 0),
#  ('Abdullah Montenegro', 'La conquista de el caos', 'Ximena Jimenez', 6, 0),
#  ('Abdullah Montenegro', 'La conquista de la ley', 'Ursula Lopes', 4, 0),
#  ('Abdullah Montenegro', 'La maldición del vampiro de la sombra', 'Mehmet Yilmaz', 3, 0),
#  ('Abdullah Montenegro', 'La resurrección de el faro', 'Omar Goncalves', 3, 0),
#  ('Abdullah Sousa', 'El descubrimiento de la luna', 'Valentina Lima', 6, 0),
#  ('Abdullah Urbina', 'La travesía del océano de la expedición', 'Isa Ivanov', 2, 0),
#  ('Abdullah Urbina', 'La travesura de la guerra', 'Emiko Gao', 1, 0),
#  ('Alessandro Lima', 'El tesoro escondido de el hechizo', 'Xavier Duarte', 6, 6),
#  ('Alessandro Xavier', 'El caballero de el faro', 'Xavier Correia', 5, 0),
#  ('Alessandro Xavier', 'La fuente de la cueva', 'Rania Estevez', 6, 0),
#  ('Beatriz Iglesias', 'El camino hacia la pesadilla', 'Oscar Xia', 3, 0),
#  ('Beatriz Iglesias', 'El tesoro escondido de el viajero', 'Elena Montenegro', 4, 4),
#  ('Beatriz Iglesias', 'El último viaje de el enigma', 'Qiu Tan', 3, 0),
#  ('Beatriz Iglesias', 'La maldición de la ley', 'Omar Quintana', 1, 0),
#  ('Bianca Iglesias', 'La escalada de la traición', 'Chen Velez', 3, 0),
#  ('Bianca Iglesias', 'La estirpe de el ángel', 'Sakura Martinez', 5, 0),
#  ('Bianca Iglesias', 'La sombra de la senda', 'Zara Nguyen', 5, 0),
#  ('Bianca Iglesias', 'La travesía de el destino', 'Patricia Oliveira', 6, 0),
#  ('Bianca Nguyen', 'El descubrimiento de la luna', 'Valentina Lima', 6, 0),
#  ('Bianca Sousa', 'La llegada de la batalla', 'Ximena Jimenez', 6, 0),
#  ('Bianca Xu', 'El ritual de la revelación', 'Jin Yilmaz', 5, 5),
#  ('Bianca Xu', 'La búsqueda del tesoro de el guardián', 'Chiyoko Fernandes', 4, 0),
#  ('Bianca Xu', 'La cripta de la tierra', 'Nadia Hernandez', 4, 0),
#  ('Chen Ueno', 'El ritual de la revelación', 'Jin Yilmaz', 5, 5),
#  ('Chen Ueno', 'La estirpe de la fortuna', 'Xavier Correia', 5, 0),
#  ('Chen Ueno', 'La venganza de la batalla', 'Rosa Abadi', 2, 0),
#  ('Chen Vargas', 'El arco iris de la trampa', 'Chen Xia', 3, 0),
#  ('Chen Vargas', 'El laberinto de el héroe', 'Mehmet Dutta', 7, 0),
#  ('Chen Xu', 'El destino de el legado', 'Leonardo Xia', 3, 0),
#  ('Chidike Carvalho', 'La estirpe de la fortuna', 'Xavier Correia', 5, 0),
#  ('Chidike Gao', 'El pacto de el mago', 'Han Janssen', 3, 0),
#  ('Chidike Gao', 'El prisionero de la despedida', 'Wan Bianchi', 7, 7),
#  ('Chidike Gao', 'El secreto oscuro de la fortuna', 'Patricia Oliveira', 6, 0),
#  ('Chidike Gao', 'El vuelo de la flor', 'Umberto Ramos', 4, 0),
#  ('Chidike Ramos', 'La senda de el peligro', 'Wan Qian', 4, 4),
#  ('Chiyoko Ivanov', 'El arco iris de el río', 'Mehmet Dutta', 7, 0),
#  ('Chiyoko Ivanov', 'La estirpe de el bosque', 'Wan Xavier', 4, 0),
#  ('Chiyoko Ivanov', 'La sombra de la profecía', 'Leticia Pereira', 2, 0),
#  ('Darius Yilmaz', 'El hechizo de el lamento', 'Fabiana Goncalves', 2, 0),
#  ('Darius Yilmaz', 'El misterio de la oscuridad', 'Katarina Janssen', 4, 0),
#  ('Darius Yilmaz', 'La venganza de el dragón', 'Darya Hernandez', 4, 0),
#  ('Darya Abadi', 'La escalada de el guardián', 'Ursula Queiroz', 3, 0),
#  ('Darya Abadi', 'La maldición del vampiro de la sombra', 'Mehmet Yilmaz', 3, 0),
#  ('Darya Xu', 'El misterio de el amanecer', 'Natalia Lima', 1, 0),
#  ('Darya Xu', 'La invasión de la cripta', 'Rosa Borges', 2, 0),
#  ('Darya Xu', 'La travesía de el amanecer', 'Wang Zhang', 9, 0),
#  ('Elena Alvarez', 'El canto de sirena de el león', 'Yasmin Mendes', 5, 5),
#  ('Elena Henriquez', 'El despertar de la estrella fugaz', 'Abdullah Carvalho', 6, 6),
#  ('Elena Henriquez', 'La conquista de la ley', 'Ursula Lopes', 4, 0),
#  ('Elena Xu', 'La danza macabra de la cripta', 'Tatjana Henriquez', 2, 0),
#  ('Elif Ramos', 'El regreso de el vuelo', 'Valentina Lima', 6, 0),
#  ('Elif Ramos', 'La llave de la muralla', 'Xavier Duarte', 6, 6),
#  ('Elif Ramos', 'La profecía de la luna', 'Rashid Zhang', 2, 0),
#  ('Elif Wu', 'El destino de la libertad', 'Tatjana Qian', 3, 0),
#  ('Elif Wu', 'El lamento de la gárgola', 'Fatemeh Zapata', 3, 0),
#  ('Elif Wu', 'El refugio de la prisión', 'Mikhail Rocha', 2, 2),
#  ('Elif Wu', 'La senda de el rey', 'Genghis Tan', 9, 0),
#  ('Emiko Borges', 'La estirpe de la fortuna', 'Xavier Correia', 5, 0),
#  ('Emiko Yilmaz', 'El tesoro escondido de el caos', 'Quentin Zapata', 2, 0),
#  ('Fabiana Quintana', 'El laberinto de el héroe', 'Mehmet Dutta', 7, 0),
#  ('Fabiana Quintana', 'La venganza de la pesadilla', 'Mikhail Mendes', 2, 0),
#  ('Fabiana Zhang', 'El tesoro escondido de el abismo', 'Mina Joaquim', 3, 0),
#  ('Fadhila Carvalho', 'La resurrección de la luz', 'Zafar Mendes', 3, 0),
#  ('Fadhila Carvalho', 'La senda de el renacimiento', 'Omar Duarte', 6, 6),
#  ('Fadhila Kawaguchi', 'El guardián de la sirena', 'Khaled Petrov', 2, 2),
#  ('Fadhila Kawaguchi', 'El pacto de la montaña', 'Genghis Tan', 9, 0),
#  ('Fatemeh Dutta', 'El renacimiento de la noche', 'Wan Qian', 4, 4),
#  ('Fatemeh Dutta', 'El último viaje de el susurro', 'Umberto Quintana', 4, 0),
#  ('Fatemeh Dutta', 'La danza macabra de el bosque', 'Nadia Santos', 4, 0),
#  ('Fatemeh Dutta', 'La senda de la espada mágica', 'Xin Quintana', 2, 0),
#  ('Fatemeh Sousa', 'El guardián de el laberinto', 'Zara Pacheco', 3, 0),
#  ('Fatemeh Sousa', 'El prisionero de la corona', 'Genghis Tan', 9, 0),
#  ('Fatemeh Sousa', 'El último viaje de el héroe', 'Leonardo Nogueira', 7, 0),
#  ('Fatemeh Uchoa', 'La tormenta de el renacer', 'Rania Olivares', 4, 0),
#  ('Genghis Kumar', 'La redención de el destino', 'Leonardo Nogueira', 7, 0),
#  ('Genghis Kumar', 'La sombra de la fuga', 'Lakshmi Lopes', 3, 0),
#  ('Genghis Lopez', 'La senda de el guardián', 'Rania Olivares', 4, 0),
#  ('Genghis Lopez', 'La travesía sin retorno de la senda', 'Darya Teles', 5, 0),
#  ('Genghis Yilmaz', 'La maldición del vampiro de el puente', 'Qiu Zapata', 1, 0),
#  ('Genghis Yilmaz', 'La travesía de el amanecer', 'Wang Zhang', 9, 0),
#  ('Giovanni Abadi', 'El vuelo mágico de el misterio', 'Hanako Gao', 5, 0),
#  ('Giovanni Abadi', 'La metamorfosis de el unicornio', 'Chiyoko Santos', 2, 0),
#  ('Giovanni Quintana', 'El ritual de la revelación', 'Jin Yilmaz', 5, 5),
#  ('Giovanni Quintana', 'La fortuna de la prisión', 'Mina Joaquim', 3, 0),
#  ('Han Alvarez', 'La senda de el amor', 'Zara Vieira', 4, 0),
#  ('Han Alvarez', 'La senda de el peligro', 'Wan Qian', 4, 4),
#  ('Han Barros', 'El misterio de la oscuridad', 'Katarina Janssen', 4, 0),
#  ('Han Barros', 'El renacimiento de la caza', 'Leonardo Ramos', 5, 5),
#  ('Han Barros', 'El tesoro escondido de el caos', 'Quentin Zapata', 2, 0),
#  ('Hanako Goncalves', 'El espejismo de la pesadilla', 'Rania Estevez', 6, 0),
#  ('Hanako Rodriguez', 'El hechizo de la resistencia', 'Zoya Henriquez', 8, 0),
#  ('Hanako Rodriguez', 'El misterio de la oscuridad', 'Katarina Janssen', 4, 0),
#  ('Hanako Rodriguez', 'La invasión de el rey', 'Xavier Duarte', 6, 6),
#  ('Hanako Xavier', 'El vuelo mágico de el castillo', 'Elena Inácio', 2, 0),
#  ('Hanako Xavier', 'La búsqueda de la batalla', 'Jin Yilmaz', 5, 5),
#  ('Hanako Xavier', 'La resurrección de el faro', 'Omar Goncalves', 3, 0),
#  ('Hanako Yilmaz', 'El despertar de el amanecer', 'Isa Rocha', 2, 0),
#  ('Hiroko Gao', 'El enigma de la esperanza', 'Lakshmi Yilmaz', 7, 0),
#  ('Hiroko Gao', 'La leyenda de el renacimiento', 'Genghis Tan', 9, 0),
#  ('Hiroko Inácio', 'El príncipe de el laberinto', 'Oscar Duarte', 2, 0),
#  ('Hiroko Inácio', 'La cripta de la estrella', 'Khaled Jimenez', 1, 1),
#  ('Hiroko Inácio', 'La danza macabra de el bosque', 'Nadia Santos', 4, 0),
#  ('Hiroko Inácio', 'La maldición de la noche', 'Emiko Henriquez', 6, 0),
#  ('Hiroko Inácio', 'La resurrección de el faro', 'Omar Goncalves', 3, 0),
#  ('Hiroko Inácio', 'La sombra de la fuga', 'Lakshmi Lopes', 3, 0),
#  ('Hiroko Inácio', 'La travesía del océano de la expedición', 'Isa Ivanov', 2, 0),
#  ('Hiroko Lima', 'El despertar de la estrella fugaz', 'Abdullah Carvalho', 6, 6),
#  ('Hiroko Lima', 'El secreto de la luz', 'Ximena Jimenez', 6, 0),
#  ('Hiroko Lima', 'La travesura de el viaje', 'Zoya Henriquez', 8, 0),
#  ('Hiroko Montenegro', 'El caballero de la fuga', 'Han Fernandes', 4, 4),
#  ('Hiroko Montenegro', 'El prisionero de el mar', 'Parvati Pereira', 2, 0),
#  ('Hiroko Montenegro', 'La estrella fugaz de el caos', 'Omar Martinez', 3, 0),
#  ('Hiroko Ortega', 'La senda de la espada mágica', 'Xin Quintana', 2, 0),
#  ('Hiroko Sousa', 'El castillo de la resistencia', 'Nadia Santos', 4, 0),
#  ('Hiroko Sousa', 'El destino de la libertad', 'Tatjana Qian', 3, 0),
#  ('Hiroko Sousa', 'El vuelo de la batalla', 'Mina Santos', 4, 0),
#  ('Hiroko Sousa', 'La invasión de la cripta', 'Rosa Borges', 2, 0),
#  ('Hiroko Teles', 'La venganza de el bosque', 'Nadia Alvarez', 4, 0),
#  ('Ilya Esteves', 'El enigma de la esperanza', 'Lakshmi Yilmaz', 7, 0),
#  ('Ilya Esteves', 'La llegada de la batalla', 'Ximena Jimenez', 6, 0),
#  ('Ilya Santos', 'El bosque encantado de el sapo', 'Mehmet Yilmaz', 3, 0),
#  ('Ilya Zambrano', 'La estrella fugaz de el caos', 'Omar Martinez', 3, 0),
#  ('Irina Lopez', 'El espejismo de el vuelo', 'Chen Velez', 3, 0),
#  ('Irina Lopez', 'El pacto de el camino', 'Elena Kawaguchi', 4, 4),
#  ('Irina Lopez', 'El renacimiento de la noche', 'Wan Qian', 4, 4),
#  ('Irina Lopez', 'La búsqueda del tesoro de la espada mágica', 'Wang Zhang', 9, 0),
#  ('Irina Rocha', 'El grito de la pesadilla', 'Quintus Velez', 4, 0),
#  ('Irina Rocha', 'El renacimiento de la caza', 'Leonardo Ramos', 5, 5),
#  ('Irina Rocha', 'La fuente de la noche', 'Nadia Alvarez', 4, 0),
#  ('Irina Rocha', 'La invasión de el hechicero', 'Valeria Vargas', 1, 0),
#  ('Isa Martinez', 'El secreto oscuro de la fortuna', 'Patricia Oliveira', 6, 0),
#  ('Isa Martinez', 'El vuelo mágico de la cárcel', 'Zara Vieira', 4, 0),
#  ('Isa Martinez', 'La fuente de la noche', 'Nadia Alvarez', 4, 0),
#  ('Isa Martinez', 'La historia de el encuentro', 'Alessandro Lopes', 5, 0),
#  ('Isa Quintana', 'El lamento de la gárgola', 'Fatemeh Zapata', 3, 0),
#  ('Isa Quintana', 'La fuente de la noche', 'Nadia Alvarez', 4, 0),
#  ('Isa Quintana', 'La tormenta de el río', 'Fatemeh Martinez', 3, 0),
#  ('Isa Santana', 'La canción de el grito', 'Mehmet Dutta', 7, 0),
#  ('Isa Santana', 'La llave de la aldea', 'Darya Teles', 5, 0),
#  ('Isa Santana', 'La maldición del vampiro de la leyenda', 'Natalia Iglesias', 1, 0),
#  ('Javier Almeida', 'La sombra de la profecía', 'Leticia Pereira', 2, 0),
#  ('Javier Borges', 'El vuelo mágico de el castillo', 'Elena Inácio', 2, 0),
#  ('Javier Borges', 'La búsqueda del tesoro de la espada mágica', 'Wang Zhang', 9, 0),
#  ('Javier Borges', 'La redención de la selva', 'Bianca Teles', 2, 0),
#  ('Javier Sousa', 'El amanecer de el mito', 'Wan Bianchi', 7, 7),
#  ('Javier Sousa', 'La llave de la muralla', 'Xavier Duarte', 6, 6),
#  ('Jin Vargas', 'El vuelo mágico de el misterio', 'Hanako Gao', 5, 0),
#  ('Jin Vargas', 'La danza de la bruma', 'Jasmin Xavier', 3, 0),
#  ('Jin Vargas', 'La escalada de el guardián', 'Ursula Queiroz', 3, 0),
#  ('Kamala Abadi', 'El descubrimiento de la luna', 'Valentina Lima', 6, 0),
#  ('Kamala Abadi', 'La danza de la guerra', 'Wang Montenegro', 1, 0),
#  ('Kamala Diniz', 'El enigma de la esperanza', 'Lakshmi Yilmaz', 7, 0),
#  ('Kamala Diniz', 'El tesoro de el jardín', 'Rania Correia', 3, 0),
#  ('Kamala Diniz', 'La cripta de la bruma', 'Leonardo Nogueira', 7, 0),
#  ('Kamala Diniz', 'La odisea de el sueño', 'Mina Oliveira', 2, 0),
#  ('Kamala Diniz', 'La resurrección de la magia', 'Elena Montenegro', 4, 4),
#  ('Kamala Pereira', 'La escalada de la magia', 'Yusef Yamamoto', 4, 4),
#  ('Kamala Pereira', 'La llegada de la batalla', 'Ximena Jimenez', 6, 0),
#  ('Kamala Velez', 'El laberinto de la verdad', 'Abdullah Carvalho', 6, 6),
#  ('Katarina Wu', 'El viaje de la fortuna', 'Salim Carvalho', 3, 3),
#  ('Katarina Wu', 'La tormenta de el río', 'Fatemeh Martinez', 3, 0),
#  ('Khaled Barros', 'El ritual de la revelación', 'Jin Yilmaz', 5, 5),
#  ('Khaled Carvalho', 'El despertar de la bruma', 'Parvati Rocha', 1, 0),
#  ('Khaled Carvalho', 'El laberinto de el renacer', 'Chiyoko Fernandes', 4, 0),
#  ('Khaled Carvalho', 'La cripta de la tierra', 'Nadia Hernandez', 4, 0),
#  ('Khaled Carvalho', 'La danza de la bruma', 'Jasmin Xavier', 3, 0),
#  ('Khaled Carvalho', 'La travesía sin retorno de la gruta', 'Umberto Quintana', 4, 0),
#  ('Khaled Hidalgo', 'El despertar de el amanecer', 'Isa Rocha', 2, 0),
#  ('Khaled Hidalgo', 'El tesoro de la tierra', 'Elif Goncalves', 1, 0),
#  ('Khaled Hidalgo', 'La maldición del vampiro de la tierra', 'Chen Xia', 3, 0),
#  ('Khaled Hidalgo', 'La senda de el renacimiento', 'Omar Duarte', 6, 6),
#  ('Khaled Hidalgo', 'La travesía sin retorno de la traición', 'Genghis Tan', 9, 0),
#  ('Khaled Hidalgo', 'La venganza de la sonrisa', 'Fabiana Dutta', 3, 0),
#  ('Khaled Vieira', 'El despertar de la cárcel', 'Rania Correia', 3, 0),
#  ('Khaled Vieira', 'El secreto de el rey', 'Giovanni Watanabe', 3, 0),
#  ('Khaled Vieira', 'La travesía sin retorno de la senda', 'Darya Teles', 5, 0),
#  ('Lakshmi Henriquez', 'El destino de la libertad', 'Tatjana Qian', 3, 0),
#  ('Lakshmi Henriquez', 'El enigma de la esperanza', 'Lakshmi Yilmaz', 7, 0),
#  ('Lakshmi Henriquez', 'El refugio de la fuga', 'Samir Abadi', 7, 0),
#  ('Lakshmi Henriquez', 'El renacimiento de la cripta', 'Mikhail Wu', 3, 0),
#  ('Lakshmi Henriquez', 'La conquista de la ley', 'Ursula Lopes', 4, 0),
#  ('Lakshmi Henriquez', 'La venganza de la sonrisa', 'Fabiana Dutta', 3, 0),
#  ('Lakshmi Janssen', 'El descubrimiento de la aventura', 'Samir Abadi', 7, 0),
#  ('Lakshmi Janssen', 'El despertar de la nube', 'Chidike Jimenez', 1, 0),
#  ('Lakshmi Janssen', 'El laberinto de el atardecer', 'Mina Santos', 4, 0),
#  ('Lakshmi Janssen', 'El lamento de la gárgola', 'Fatemeh Zapata', 3, 0),
#  ('Lakshmi Janssen', 'La búsqueda del tesoro de el guardián', 'Chiyoko Fernandes', 4, 0),
#  ('Lakshmi Ramos', 'El cuento de hadas de el abismo', 'Nadia Yilmaz', 2, 0),
#  ('Lakshmi Ramos', 'El prisionero de la corona', 'Genghis Tan', 9, 0),
#  ('Lakshmi Ramos', 'La conquista de la guerra', 'Lakshmi Yilmaz', 7, 0),
#  ('Leonardo Goncalves', 'La canción de la leyenda', 'Ximena Goncalves', 2, 0),
#  ('Leonardo Goncalves', 'La odisea de la oscuridad', 'Ximena Uchoa', 2, 0),
#  ('Leonardo Goncalves', 'La tormenta de el río', 'Fatemeh Martinez', 3, 0),
#  ('Leonardo Olivares', 'El caballero de la aventura', 'Chiyoko Fernandes', 4, 0),
#  ('Leonardo Olivares', 'El pacto de el río', 'Wan Bianchi', 7, 7),
#  ('Leonardo Olivares', 'El refugio de el trono', 'Rania Estevez', 6, 0),
#  ('Leonardo Olivares', 'El refugio de la prisión', 'Mikhail Rocha', 2, 2),
#  ('Leonardo Zambrano', 'El prisionero de la corona', 'Genghis Tan', 9, 0),
#  ('Leonardo Zambrano', 'La venganza de la pesadilla', 'Mikhail Mendes', 2, 0),
#  ('Leticia Lopes', 'El hechizo de la flor', 'Zafar Mendes', 3, 0),
#  ('Leticia Lopes', 'El laberinto de el héroe', 'Mehmet Dutta', 7, 0),
#  ('Mehmet Ferreira', 'El castillo de la resistencia', 'Nadia Santos', 4, 0),
#  ('Mehmet Ferreira', 'El destino de el rincón', 'Ximena Bianchi', 4, 0),
#  ('Mehmet Ferreira', 'El pacto de la montaña', 'Genghis Tan', 9, 0),
#  ('Mehmet Ferreira', 'El secreto oscuro de la fortuna', 'Patricia Oliveira', 6, 0),
#  ('Mehmet Ferreira', 'El tesoro escondido de el hechizo', 'Xavier Duarte', 6, 6),
#  ('Mehmet Lopes', 'La historia de el encuentro', 'Alessandro Lopes', 5, 0),
#  ('Mikhail Dutta', 'El enigma de la huida', 'Zafar Bianchi', 1, 0),
#  ('Mikhail Pacheco', 'El arco iris de la pesadilla', 'Mikhail Ramos', 2, 0),
#  ('Mikhail Pacheco', 'El pacto de el camino', 'Elena Kawaguchi', 4, 4),
#  ('Mina Gao', 'El vuelo mágico de el viaje', 'Sakura Martinez', 5, 0),
#  ('Mina Gao', 'La búsqueda de la magia', 'Ximena Bianchi', 4, 0),
#  ('Mina Gao', 'La invasión de la noche', 'Wan Xavier', 4, 0),
#  ('Mina Gao', 'La trampa de la ley', 'Parvati Pereira', 2, 0),
#  ('Mina Watanabe', 'El refugio de la fuga', 'Samir Abadi', 7, 0),
#  ('Mina Watanabe', 'El tesoro escondido de el hechizo', 'Xavier Duarte', 6, 6),
#  ('Mina Watanabe', 'La estirpe de el bosque', 'Wan Xavier', 4, 0),
#  ('Mina Watanabe', 'La travesía sin retorno de la senda', 'Darya Teles', 5, 0),
#  ('Mina Watanabe', 'La travesura de el viaje', 'Zoya Henriquez', 8, 0),
#  ('Nadia Gomes', 'El renacimiento de la caza', 'Leonardo Ramos', 5, 5),
#  ('Nadia Gomes', 'El secreto oscuro de la ciudad', 'Yasmin Mendes', 5, 5),
#  ('Nadia Gomes', 'La danza de el puente', 'Kamala Fernandes', 2, 0),
#  ('Nadia Gomes', 'La leyenda de el rincón', 'Aarav Mendes', 1, 1),
#  ('Nadia Gomes', 'La senda de la criatura', 'Xavier Barros', 3, 0),
#  ('Nadia Vargas', 'El renacimiento de la cripta', 'Mikhail Wu', 3, 0),
#  ('Nadia Vargas', 'El vuelo mágico de el misterio', 'Hanako Gao', 5, 0),
#  ('Nadia Vargas', 'La escalada de la traición', 'Chen Velez', 3, 0),
#  ('Nadia Vargas', 'La travesura de el viaje', 'Zoya Henriquez', 8, 0),
#  ('Nadia Xia', 'El arco iris de el río', 'Mehmet Dutta', 7, 0),
#  ('Nadia Xia', 'El refugio de el perdón', 'Javier Ueno', 3, 0),
#  ('Natalia Yan', 'La canción de la montaña', 'Omar Duarte', 6, 6),
#  ('Natalia Yan', 'La conquista de el sol', 'Emiko Henriquez', 6, 0),
#  ('Nina Yamamoto', 'La sombra de la senda', 'Zara Nguyen', 5, 0),
#  ('Omar Abadi', 'El grito de la pesadilla', 'Quintus Velez', 4, 0),
#  ('Omar Abadi', 'El hechizo de la compañía', 'Zara Nguyen', 5, 0),
#  ('Omar Abadi', 'La tormenta de la sirena', 'Alessandro Lopes', 5, 0),
#  ('Omar Abadi', 'La travesura de el muro', 'Emiko Henriquez', 6, 0),
#  ('Omar Correia', 'La maldición del vampiro de la gárgola', 'Yusef Yamamoto', 4, 4),
#  ('Omar Quintana', 'El vuelo de la flor', 'Umberto Ramos', 4, 0),
#  ('Omar Quintana', 'La búsqueda del tesoro de la espada mágica', 'Wang Zhang', 9, 0),
#  ('Orhan Alvarez', 'El camino hacia la pesadilla', 'Oscar Xia', 3, 0),
#  ('Orhan Kawaguchi', 'El último viaje de el enigma', 'Qiu Tan', 3, 0),
#  ('Orhan Kawaguchi', 'La travesía de el amanecer', 'Wang Zhang', 9, 0),
#  ('Orhan Vargas', 'El caballero de el faro', 'Xavier Correia', 5, 0),
#  ('Orhan Vargas', 'La batalla de el unicornio', 'Oscar Xia', 3, 0),
#  ('Orhan Vargas', 'La sombra de el sueño', 'Zoya Henriquez', 8, 0),
#  ('Oscar Hidalgo', 'El hechizo de el lamento', 'Fabiana Goncalves', 2, 0),
#  ('Oscar Hidalgo', 'El secreto de el destino', 'Oscar Duarte', 2, 0),
#  ('Oscar Vargas', 'El misterio de la oscuridad', 'Katarina Janssen', 4, 0),
#  ('Oscar Vargas', 'El prisionero de la sirena', 'Genghis Goncalves', 1, 1),
#  ('Oscar Vargas', 'El último viaje de el héroe', 'Leonardo Nogueira', 7, 0),
#  ('Oscar Vargas', 'El vuelo mágico de el misterio', 'Hanako Gao', 5, 0),
#  ('Parvati Fernandes', 'La escalada de la magia', 'Yusef Yamamoto', 4, 4),
#  ('Parvati Zhang', 'El refugio de la fuga', 'Samir Abadi', 7, 0),
#  ('Parvati Zhang', 'El vuelo mágico de el viaje', 'Sakura Martinez', 5, 0),
#  ('Parvati Zhang', 'La leyenda de el abismo', 'Quintus Velez', 4, 0),
#  ('Patricia Fernandes', 'El lamento de el océano', 'Genghis Wu', 1, 0),
#  ('Patricia Goncalves', 'El secreto oscuro de la fortuna', 'Patricia Oliveira', 6, 0),
#  ('Patricia Lima', 'El descubrimiento de la aventura', 'Samir Abadi', 7, 0),
#  ('Patricia Lima', 'El grito de el camino', 'Omar Duarte', 6, 6),
#  ('Patricia Lima', 'El guardián de el laberinto', 'Zara Pacheco', 3, 0),
#  ('Patricia Lima', 'El pacto de el camino', 'Elena Kawaguchi', 4, 4),
#  ('Patricia Lima', 'El refugio de el perdón', 'Javier Ueno', 3, 0),
#  ('Patricia Lima', 'El vuelo de la flor', 'Umberto Ramos', 4, 0),
#  ('Pilar Kawaguchi', 'El pacto de el enigma', 'Fadhila Teles', 4, 0),
#  ('Pilar Kawaguchi', 'El refugio de la fuga', 'Samir Abadi', 7, 0),
#  ('Qiu Pacheco', 'El vuelo mágico de el viaje', 'Sakura Martinez', 5, 0),
#  ('Qiu Tan', 'La tormenta de el mago', 'Sakura Figueiredo', 2, 0),
#  ('Qiu Yan', 'El pacto de el enigma', 'Fadhila Teles', 4, 0),
#  ('Quentin Yan', 'La redención de la selva', 'Bianca Teles', 2, 0),
#  ('Quintus Olivares', 'El destino de el rincón', 'Ximena Bianchi', 4, 0),
#  ('Quintus Olivares', 'El hechizo de el cielo', 'Valentina Carvalho', 1, 0),
#  ('Quintus Olivares', 'El viaje de la fortuna', 'Salim Carvalho', 3, 3),
#  ('Quintus Olivares', 'La estrella fugaz de el caos', 'Omar Martinez', 3, 0),
#  ('Rashid Barros', 'El cuento de hadas de el abismo', 'Nadia Yilmaz', 2, 0),
#  ('Rashid Barros', 'El tesoro escondido de el viajero', 'Elena Montenegro', 4, 4),
#  ('Rashid Barros', 'La búsqueda del tesoro de la espada mágica', 'Wang Zhang', 9, 0),
#  ('Rashid Barros', 'La fortuna de la esperanza', 'Tatjana Henriquez', 2, 0),
#  ('Rashid Teixeira', 'El hechizo de la resistencia', 'Zoya Henriquez', 8, 0),
#  ('Rashid Teixeira', 'La búsqueda de la magia', 'Ximena Bianchi', 4, 0),
#  ('Rashid Teixeira', 'La canción de la montaña', 'Omar Duarte', 6, 6),
#  ('Rashid Teixeira', 'La fuente de la cueva', 'Rania Estevez', 6, 0),
#  ('Salim Vargas', 'La escalada de la luz', 'Darya Teles', 5, 0),
#  ('Salim Vargas', 'La fuente de el cielo', 'Elena Vieira', 1, 0),
#  ('Salim Vargas', 'La llegada de el rincón', 'Salim Carvalho', 3, 3),
#  ('Salim Vargas', 'La trampa de la mariposa', 'Leticia Figueiredo', 1, 0),
#  ('Salim Xia', 'La cripta de la bruma', 'Leonardo Nogueira', 7, 0),
#  ('Samir Nogueira', 'El pacto de el río', 'Wan Bianchi', 7, 7),
#  ('Samir Nogueira', 'El resurgimiento de el encuentro', 'Patricia Petrov', 1, 1),
#  ('Samir Nogueira', 'La danza de el puente', 'Kamala Fernandes', 2, 0),
#  ('Samir Nogueira', 'La historia de el encuentro', 'Alessandro Lopes', 5, 0),
#  ('Tatiana Alvarez', 'El pacto de el enigma', 'Fadhila Teles', 4, 0),
#  ('Tatiana Alvarez', 'El último viaje de la muralla', 'Alessandro Pacheco', 1, 0),
#  ('Tatiana Alvarez', 'La misión de la caída', 'Han Janssen', 3, 0),
#  ('Tatiana Alvarez', 'La venganza de la prisión', 'Omar Duarte', 6, 6),
#  ('Tatiana Dutta', 'El enigma de la esperanza', 'Lakshmi Yilmaz', 7, 0),
#  ('Tatiana Dutta', 'El grito de la puerta', 'Khaled Petrov', 2, 2),
#  ('Tatiana Dutta', 'El prisionero de la oscuridad', 'Nina Santos', 1, 0),
#  ('Tatiana Dutta', 'La redención de el destino', 'Leonardo Nogueira', 7, 0),
#  ('Tatjana Almeida', 'El vuelo mágico de la cárcel', 'Zara Vieira', 4, 0),
#  ('Tatjana Almeida', 'La fuente de el renacimiento', 'Yasmin Mendes', 5, 5),
#  ('Tatjana Ortega', 'El laberinto de la verdad', 'Abdullah Carvalho', 6, 6),
#  ('Theresa Estevez', 'El arco iris de la trampa', 'Chen Xia', 3, 0),
#  ('Theresa Estevez', 'El último viaje de la pesadilla', 'Orhan Xia', 1, 1),
#  ('Theresa Estevez', 'La búsqueda del tesoro de la espada mágica', 'Wang Zhang', 9, 0),
#  ('Umar Figueiredo', 'La sombra de la senda', 'Zara Nguyen', 5, 0),
#  ('Umar Joaquim', 'El resurgimiento de el guardián', 'Javier Montenegro', 3, 0),
#  ('Umar Joaquim', 'La conquista de la ley', 'Ursula Lopes', 4, 0),
#  ('Umberto Almeida', 'La cripta de la tierra', 'Nadia Hernandez', 4, 0),
#  ('Umberto Almeida', 'La travesía sin retorno de el ángel', 'Javier Montenegro', 3, 0),
#  ('Umberto Pacheco', 'El laberinto de la verdad', 'Abdullah Carvalho', 6, 6),
#  ('Umberto Pacheco', 'La leyenda de el abismo', 'Quintus Velez', 4, 0),
#  ('Umberto Pacheco', 'La metamorfosis de el unicornio', 'Chiyoko Santos', 2, 0),
#  ('Umberto Uchoa', 'El hechizo de la compañía', 'Zara Nguyen', 5, 0),
#  ('Umberto Uchoa', 'El vuelo de la batalla', 'Mina Santos', 4, 0),
#  ('Ursula Carvalho', 'El caballero de la fuga', 'Han Fernandes', 4, 4),
#  ('Ursula Carvalho', 'El secreto de el rey', 'Giovanni Watanabe', 3, 0),
#  ('Ursula Uchoa', 'La travesía sin retorno de el atardecer', 'Valentina Lima', 6, 0),
#  ('Valentina Martinez', 'El pacto de el mago', 'Han Janssen', 3, 0),
#  ('Valentina Martinez', 'La llegada de el abismo', 'Han Fernandes', 4, 4),
#  ('Valentina Martinez', 'La metamorfosis de la fortuna', 'Orhan Goncalves', 1, 0),
#  ('Valentina Olivares', 'El destino de el legado', 'Leonardo Xia', 3, 0),
#  ('Valentina Olivares', 'El laberinto de la magia', 'Zafar Mendes', 3, 0),
#  ('Valentina Olivares', 'La leyenda de el secreto', 'Mikhail Ramos', 2, 0),
#  ('Valentina Olivares', 'La resurrección de la magia', 'Elena Montenegro', 4, 4),
#  ('Valeria Hernandez', 'La sombra de la fuga', 'Lakshmi Lopes', 3, 0),
#  ('Valeria Vargas', 'La invasión de la libertad', 'Ursula Queiroz', 3, 0),
#  ('Valeria Vargas', 'La profecía de el bosque', 'Leonardo Ramos', 5, 5),
#  ('Wan Ortega', 'El enigma de el río', 'Emiko Henriquez', 6, 0),
#  ('Wan Ortega', 'El guardián de el laberinto', 'Zara Pacheco', 3, 0),
#  ('Wan Ortega', 'La estrella fugaz de la luna', 'Alessandro Lopes', 5, 0),
#  ('Wan Ortega', 'La tormenta de el renacer', 'Rania Olivares', 4, 0),
#  ('Wan Ortega', 'La trampa de el guerrero', 'Hiroko Uchoa', 3, 3),
#  ('Wan Ortega', 'La travesía de el amanecer', 'Wang Zhang', 9, 0),
#  ('Wang Gomes', 'El vuelo de la flor', 'Umberto Ramos', 4, 0),
#  ('Wang Gomes', 'La canción de el grito', 'Mehmet Dutta', 7, 0),
#  ('Wang Gomes', 'La profecía de la luna', 'Rashid Zhang', 2, 0),
#  ('Wang Joaquim', 'El vuelo de la batalla', 'Mina Santos', 4, 0),
#  ('Wang Joaquim', 'El vuelo mágico de el ángel', 'Xavier Vargas', 1, 0),
#  ('Wang Joaquim', 'La invasión de la profecía', 'Zoya Joaquim', 1, 0),
#  ('Wang Joaquim', 'La leyenda de la estrella fugaz', 'Yasmin Ivanov', 1, 0),
#  ('Wilhelmina Ramos', 'El enigma de la esperanza', 'Lakshmi Yilmaz', 7, 0),
#  ('Wilhelmina Ramos', 'El último viaje de el susurro', 'Umberto Quintana', 4, 0),
#  ('Xavier Iglesias', 'La travesía del océano de el legado', 'Ximena Wu', 2, 0),
#  ('Xavier Iglesias', 'Las aventuras de el bosque', 'Mikhail Wu', 3, 0),
#  ('Ximena Uchoa', 'La escalada de la princesa', 'Dmitri Dutta', 1, 1),
#  ('Xin Martinez', 'El bosque encantado de la tierra', 'Hanako Gao', 5, 0),
#  ('Xin Martinez', 'El descubrimiento de la libertad', 'Darya Hernandez', 4, 0),
#  ('Xin Martinez', 'El grito de la prisión', 'Mina Oliveira', 2, 0),
#  ('Xin Martinez', 'La maldición del vampiro de la gárgola', 'Yusef Yamamoto', 4, 4),
#  ('Xin Martinez', 'La resurrección de el jardín', 'Rania Olivares', 4, 0),
#  ('Xin Ueno', 'La fuente de el renacimiento', 'Yasmin Mendes', 5, 5),
#  ('Yasmin Joaquim', 'El pacto de el camino', 'Elena Kawaguchi', 4, 4),
#  ('Yasmin Joaquim', 'El refugio de la fuga', 'Samir Abadi', 7, 0),
#  ('Yasmin Joaquim', 'El último viaje de la leyenda', 'Gustavo Ortega', 1, 0),
#  ('Yasmin Joaquim', 'La fuente de la cueva', 'Rania Estevez', 6, 0),
#  ('Yasmin Joaquim', 'La llegada de la batalla', 'Ximena Jimenez', 6, 0),
#  ('Yasmin Joaquim', 'La sombra de el sueño', 'Zoya Henriquez', 8, 0),
#  ('Yasmin Santana', 'El destino de el legado', 'Leonardo Xia', 3, 0),
#  ('Yasmin Santana', 'La canción de la leyenda', 'Ximena Goncalves', 2, 0),
#  ('Yasmin Santana', 'La travesura de el viaje', 'Zoya Henriquez', 8, 0),
#  ('Yusef Dutta', 'El espejismo de la pesadilla', 'Rania Estevez', 6, 0),
#  ('Yusef Dutta', 'La búsqueda de el océano', 'Tatjana Petrov', 1, 1),
#  ('Yusef Dutta', 'La danza de la bruma', 'Jasmin Xavier', 3, 0),
#  ('Yusef Figueiredo', 'El espejismo de el monstruo', 'Hanako Rocha', 1, 0),
#  ('Yusef Figueiredo', 'La conquista de el sol', 'Emiko Henriquez', 6, 0),
#  ('Yusef Figueiredo', 'La resurrección de la luna', 'Javier Ueno', 3, 0),
#  ('Yusef Figueiredo', 'La tormenta de el mago', 'Sakura Figueiredo', 2, 0),
#  ('Yusef Pacheco', 'El vuelo mágico de la cárcel', 'Zara Vieira', 4, 0),
#  ('Zafar Correia', 'La invasión de la noche', 'Wan Xavier', 4, 0),
#  ('Zafar Henriquez', 'El camino hacia el grito', 'Fabiana Dutta', 3, 0),
#  ('Zafar Henriquez', 'El enigma de el destino', 'Leonardo Alvarez', 1, 0),
#  ('Zafar Henriquez', 'La trampa de la muralla', 'Wan Bianchi', 7, 7),
#  ('Zafar Wu', 'El caballero de la compañía', 'Pilar Santos', 1, 0),
#  ('Zafar Wu', 'El resurgimiento de el guardián', 'Javier Montenegro', 3, 0),
#  ('Zara Barros', 'El secreto oscuro de la ciudad', 'Yasmin Mendes', 5, 5),
#  ('Zara Barros', 'El tesoro escondido de el abismo', 'Mina Joaquim', 3, 0),
#  ('Zara Barros', 'La trampa de el guerrero', 'Hiroko Uchoa', 3, 3),
#  ('Zara Barros', 'La travesura de el muro', 'Emiko Henriquez', 6, 0),
#  ('Zara Martinez', 'El secreto oscuro de la prisión', 'Fadhila Teles', 4, 0),
#  ('Zara Martinez', 'La estirpe de el ángel', 'Sakura Martinez', 5, 0),
#  ('Zara Vargas', 'El descubrimiento de la libertad', 'Darya Hernandez', 4, 0),
#  ('Zara Vargas', 'El espejismo de la pesadilla', 'Rosa Abadi', 2, 0),
#  ('Zara Zhang', 'La trampa de la muralla', 'Wan Bianchi', 7, 7),
#  ('Zoya Lopez', 'El caballero de la fuga', 'Han Fernandes', 4, 4),
#  ('Zoya Lopez', 'La cripta de la tierra', 'Nadia Hernandez', 4, 0),
#  ('Zoya Martinez', 'El renacimiento de la caza', 'Leonardo Ramos', 5, 5),
#  ('Zoya Vargas', 'El bosque encantado de el destino', 'Abdullah Carvalho', 6, 6),
#  ('Zoya Vargas', 'El canto de sirena de la corrupción', 'Leonardo Nogueira', 7, 0),
#  ('Zoya Vargas', 'El secreto de el rey', 'Giovanni Watanabe', 3, 0),
#  ('Zoya Vargas', 'La odisea de la oscuridad', 'Ximena Uchoa', 2, 0),
#  ('Zoya Vargas', 'La senda de la criatura', 'Xavier Barros', 3, 0)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
